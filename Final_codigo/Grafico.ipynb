# %%
comunas = {'santiago': 7, 'renca': 8, 'maipu': 17, 'puente_alto': 8, 'san_bernardo': 8, 'sano_joaquin': 24, 'la_pintana': 20, 
 'el_bosque': 13, 'penalolen': 15, 'cerro_navia': 6, 'pudahuel': 27, 'macul': 18, 'cerrillos': 12, 'la_florida': 16, 
 'recoleta': 9, 'la_granja': 15}

# %%
import matplotlib.pyplot as plt
img = plt.imread("imagenes/mapa2.png")
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(img, extent=[0, 1700, 0, 1600])
x_comuna = [720,300,300,1100,550,820,800,630,1200,400,250,950,480,1050,800,850]
y_comuna = [900,1200,600,270,200,710,350,450,780,1050,1000,750,760,600,1130,550]

ax.scatter(x_comuna, y_comuna, marker='o', color=['red'],s=5)

n=[]

for comuna in comunas:
    n.append(comunas[comuna])

for i, txt in enumerate(n):
    ax.annotate(txt, (x_comuna[i], y_comuna[i]),color='black',size=20)
